# %%
import pandas as pd

#ventas = pd.read

# %% [markdown]
# #importo archivo desde la sesion actual

# %%
ventas = pd.read_csv("/content/ventas.csv")
print(ventas)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_6638/531979157.py in <cell line: 0>()
# ----> 1 ventas = pd.read_csv("/content/ventas.csv")
#       2 print(ventas)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
print('Primeras 10 filas:\n', ventas.head(10))
# Out:
# Primeras 10 filas:
#          Fecha     Vendedor Sede Entrega    Producto     Importe
# 0  06/11/2020  Vendedor 10       Sede D  Producto Z   $75880.72
# 1  01/10/2021  Vendedor 10       Sede D  Producto Y  $279412.05
# 2  09/05/2021   Vendedor 4       Sede A  Producto W         NaN
# 3  07/10/2021   Vendedor 3       Sede D  Producto U   $33830.98
# 4  02/08/2021   Vendedor 3       Sede C  Producto U  $205706.84
# 5  16/12/2020   Vendedor 5       Sede A  Producto V  $107878.61
# 6  09/04/2021   Vendedor 7       Sede A  Producto V   $90188.96
# 7  04/10/2021   Vendedor 2       Sede B  Producto Z   $83816.29
# 8  25/09/2021   Vendedor 1       Sede A  Producto X  $115339.04
# 9  22/04/2021   Vendedor 6       Sede B  Producto V  $374378.47

# %%
url = "https://docs.google.com/spreadsheets/d/1ZUp9wydRFQYBiLurFmSmfAPnWTG3Np4s59Pz6YPDwdI/export?format=csv"
ventas2 = pd.read_csv(url)
print(ventas2.head(10))
#leer útilmas 10 filas
print(ventas2.tail(10))
# Out:
#         Fecha     Vendedor Sede Entrega    Producto     Importe
# 0  06/11/2020  Vendedor 10       Sede D  Producto Z   $75880.72
# 1  01/10/2021  Vendedor 10       Sede D  Producto Y  $279412.05
# 2  09/05/2021   Vendedor 4       Sede A  Producto W         NaN
# 3  07/10/2021   Vendedor 3       Sede D  Producto U   $33830.98
# 4  02/08/2021   Vendedor 3       Sede C  Producto U  $205706.84
# 5  16/12/2020   Vendedor 5       Sede A  Producto V  $107878.61
# 6  09/04/2021   Vendedor 7       Sede A  Producto V   $90188.96
# 7  04/10/2021   Vendedor 2       Sede B  Producto Z   $83816.29
# 8  25/09/2021   Vendedor 1       Sede A  Producto X  $115339.04
# 9  22/04/2021   Vendedor 6       Sede B  Producto V  $374378.47
#           Fecha     Vendedor Sede Entrega    Producto     Importe
# 944  21/10/2020   Vendedor 4       Sede C  Producto S  $122973.31
# 945  03/09/2021  Vendedor 12       Sede A  Producto Y   $76540.29
# 946  31/12/2020  Vendedor 12       Sede A  Producto P  $156715.71
# ...

# %% [markdown]
# # ver la informacion del dataFrame

# %%
print(ventas2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Fecha         954 non-null    object
#  1   Vendedor      954 non-null    object
#  2   Sede Entrega  954 non-null    object
#  3   Producto      954 non-null    object
#  4   Importe       914 non-null    object
# dtypes: object(5)
# memory usage: 37.4+ KB
# None

# %% [markdown]
# # contar datos nulos

# %%
print(ventas2.isnull().sum())
# Out:
# Fecha            0
# Vendedor         0
# Sede Entrega     0
# Producto         0
# Importe         40
# dtype: int64

# %% [markdown]
# # encontrar datos duplicados

# %%
print(ventas2.duplicated())
print(ventas2.duplicated().sum())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# Length: 954, dtype: bool
# 0

# %%
ventas2_limpio = ventas2.dropna()
print(ventas2_limpio)
# Out:
#           Fecha     Vendedor Sede Entrega    Producto     Importe
# 0    06/11/2020  Vendedor 10       Sede D  Producto Z   $75880.72
# 1    01/10/2021  Vendedor 10       Sede D  Producto Y  $279412.05
# 3    07/10/2021   Vendedor 3       Sede D  Producto U   $33830.98
# 4    02/08/2021   Vendedor 3       Sede C  Producto U  $205706.84
# 5    16/12/2020   Vendedor 5       Sede A  Producto V  $107878.61
# ..          ...          ...          ...         ...         ...
# 947  17/06/2021   Vendedor 6       Sede C  Producto T  $241054.98
# 949  20/10/2020   Vendedor 9       Sede C  Producto W   $36881.64
# 950  01/10/2021   Vendedor 1       Sede D  Producto S  $118292.73
# 952  01/05/2021   Vendedor 6       Sede A  Producto T  $262802.89
# 953  19/02/2021   Vendedor 1       Sede B  Producto O  $192582.38
#
# [914 rows x 5 columns]
