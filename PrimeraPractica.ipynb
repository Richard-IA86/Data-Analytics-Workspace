# %% [markdown]
# <a href="https://colab.research.google.com/github/Richard-IA86/Data-Analytics-Workspace/blob/main/PrimeraPractica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Hola mundo

# %% [markdown]
# # ALUMNO - RICARDO RIVAROLA
# Voy a estar participando de una clase
# Los dias martes de 19 a 20
# Los jueves en el mismo horario
#
# * Google Colab
# * Pandas
# * Numpy
#
# Clases en: https://talentotech.bue.edu.ar/home
#
# **Imagen
# <center>
# https://www.infobae.com/resizer/v2/SGXKTX7PCZAB7MIB7YFRSZJIXY.jpg?auth=ad8382d5119ddae828e95ba83aea19600084608a8bec780acc3c7e25e3d98693&smart=true&width=992&height=786&quality=85
# <center>
#
# ---
# Primer ejercicio listo!

# %%
numero = int(imput("ingrese un numero"))
if numero % 2 == 0;
